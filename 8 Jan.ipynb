# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(0, 50, 64)
data
# Out:
# array([ 0, 31, 41, 49,  5, 32, 12,  4, 18, 15,  7, 38, 47, 28, 48, 41, 32,
#        44,  8, 27, 10,  8, 36, 12, 21, 13, 20, 16, 32, 35, 26, 24, 15,  4,
#         2, 27, 33, 23, 11, 12, 46, 20,  4, 34, 15, 30, 13, 46, 38,  0, 35,
#         3,  3, 15,  3, 28, 30, 49, 43,  5, 42, 29, 27,  0])

# %%
img = data.reshape(8, 8)
img
# Out:
# array([[ 0, 31, 41, 49,  5, 32, 12,  4],
#        [18, 15,  7, 38, 47, 28, 48, 41],
#        [32, 44,  8, 27, 10,  8, 36, 12],
#        [21, 13, 20, 16, 32, 35, 26, 24],
#        [15,  4,  2, 27, 33, 23, 11, 12],
#        [46, 20,  4, 34, 15, 30, 13, 46],
#        [38,  0, 35,  3,  3, 15,  3, 28],
#        [30, 49, 43,  5, 42, 29, 27,  0]])

# %%
plt.imshow(img)
plt.show()

# %%
data2 = np.random.randint(0, 255, 12000000)
data2
# Out:
# array([179, 150, 100, ...,  97,  96, 104])

# %%
img2 = data2.reshape(3000,4000)
img2
# Out:
# array([[179, 150, 100, ..., 202, 170, 209],
#        [175, 249, 195, ...,  83,  75, 168],
#        [140, 127,  90, ...,  14, 246, 225],
#        ...,
#        [223,  95, 135, ...,  51,  72,  43],
#        [122, 223, 148, ...,  76,  94, 118],
#        [ 15,  38, 193, ...,  97,  96, 104]])

# %%
plt.imshow(img2)

# %%
data3 = np.random.randint(0, 255, 1200)
data3
# Out:
# array([ 35, 180, 190, ...,  19, 249,  75])

# %%
img3 = data3.reshape(30,40)
img3
# Out:
# array([[191, 223, 232, ..., 211, 134, 243],
#        [129,  29,  48, ..., 129,  54, 135],
#        [ 24, 235,  94, ..., 112, 149, 111],
#        ...,
#        [234, 101, 138, ..., 107,  77,  12],
#        [240,  27, 251, ..., 210,  28, 126],
#        [126, 191, 101, ...,  31, 110, 157]])

# %%
plt.imshow(img3)

# %%
data4 = np.random.randint(0, 255, 192)
data4
# Out:
# array([211,  57,  95, 140, 178, 220,  90, 233,  86, 103, 140,  53, 231,
#        209, 199,  32, 143,  18,  13,  70,  57, 197,   1, 212, 221, 250,
#        190, 232, 109, 141, 109, 184,   0,  59,  33,  11,  65,  88,  85,
#        228,  51, 198, 117,  25, 205, 199, 189,  10,  78, 180, 178,  45,
#         85,  61, 206, 115, 186, 138, 125,  76,  48,  18, 191, 211, 206,
#        199,  74, 171,  65, 220, 161,  29, 130,  84, 114, 139, 253, 129,
#         41,  58, 239, 107,  66,   8, 208, 209,  53, 142, 122, 135,  13,
#         27, 163, 224, 222,  59,  84, 113,  94, 178,  48, 134, 111,  48,
#         49, 218, 146,   4,  70, 240, 187, 221, 229,  45, 209,  95, 143,
#        176,  29, 190,  51, 126, 111,  26, 217, 141, 192,  31,  69, 225,
#        156, 177,  19, 236,  48,  70,  23, 179, 133, 109, 159, 220,  68,
#        116,  22, 229, 101, 118, 142,  66, 114, 143,  34, 183, 112,  62,
#        254, 111, 243,  40,  99, 211,  71, 198, 209,  77, 132,  26,  11,
# ...

# %%
img4 = data4.reshape(8, 8, 3)
img4
# Out:
# array([[[211,  57,  95],
#         [140, 178, 220],
#         [ 90, 233,  86],
#         [103, 140,  53],
#         [231, 209, 199],
#         [ 32, 143,  18],
#         [ 13,  70,  57],
#         [197,   1, 212]],
#
#        [[221, 250, 190],
#         [232, 109, 141],
#         [109, 184,   0],
#         [ 59,  33,  11],
#         [ 65,  88,  85],
#         [228,  51, 198],
#         [117,  25, 205],
#         [199, 189,  10]],
#
#        [[ 78, 180, 178],
#         [ 45,  85,  61],
#         [206, 115, 186],
#         [138, 125,  76],
#         [ 48,  18, 191],
#         [211, 206, 199],
#         [ 74, 171,  65],
#         [220, 161,  29]],
#
#        [[130,  84, 114],
#         [139, 253, 129],
#         [ 41,  58, 239],
#         [107,  66,   8],
#         [208, 209,  53],
#         [142, 122, 135],
#         [ 13,  27, 163],
#         [224, 222,  59]],
#
#        [[ 84, 113,  94],
#         [178,  48, 134],
#         [111,  48,  49],
#         [218, 146,   4],
# ...

# %%
plt.imshow(img4)

# %%
data5 = np.random.randint(0, 255, 3600)
data5
# Out:
# array([171, 227, 207, ...,  90, 170,  71])

# %%
img5 = data5.reshape(30, 40, 3)
img5
# Out:
# array([[[171, 227, 207],
#         [246, 184,  15],
#         [238,  53,  83],
#         ...,
#         [ 77,  12,  97],
#         [194,  11, 154],
#         [210,  53, 247]],
#
#        [[ 28, 197,  50],
#         [ 28, 178,  88],
#         [244,  58, 117],
#         ...,
#         [ 19,   6,  83],
#         [ 69,   1,  66],
#         [ 97,  70,  20]],
#
#        [[ 60, 104, 108],
#         [ 55,  88, 200],
#         [ 48, 119,  12],
#         ...,
#         [174,  78,  70],
#         [250, 130,  46],
#         [125,  49, 160]],
#
#        ...,
#
#        [[ 66,  40,  14],
#         [144, 184, 234],
#         [ 33, 132, 206],
#         ...,
#         [ 84,   8, 220],
#         [204, 176,  23],
#         [153,  19, 211]],
#
#        [[143, 194, 175],
#         [ 82,  71, 201],
#         [113, 254, 116],
#         ...,
#         [ 39, 196, 168],
#         [ 63, 192,  56],
#         [ 14, 245, 224]],
#
#        [[ 83,  10, 239],
#         [197, 143,  65],
#         [ 89,  46,  84],
# ...

# %%
plt.imshow(img5)
