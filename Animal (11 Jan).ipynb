# %%
import cv2 as cv
import numpy as np

img = cv.imread("Animal.jpeg")

img = cv.resize(img, (400, 400))
cv.imshow("Original Image", img)

# -------Red---------------
# img[:,:,0] = img[:,:,1] = 0
# cv.imshow("Red Image", img)
# print(img)

# -------Green---------------
# img[:,:,0] = img[:,:,2] = 0
# cv.imshow("Green Image", img)
# print(img)

# -------Blue---------------
# img[:,:,1] = img[:,:,2] = 0
# cv.imshow("Blue Image", img)
# print(img)

"""sat = 50
hsv_img[:,:,0] = np.clip(hsv_img[:,:,0] + sat, 1, 255)"""

"""hsv_img = cv.cvtColor(img, cv.COLOR_BGR2HSV)
val = 5
hsv_img[:,:,2] = hsv_img[:,:,2] + val

sat_img = cv.cvtColor(hsv_img, cv.COLOR_HSV2BGR)"""

"""cv.rectangle(img, (100, 50),(200, 150), color=(255, 0, 0), thickness=3)
cv.circle(img, (200, 150), 50, color=(150, 14, 100), thickness=3)
cv.line(img, (200, 150), (340, 300), color=(10, 20, 30), thickness=3)"""

mask = np.zeros_like(img, dtype=np.uint8)
# print(mask)

# Circle
"""height, width = mask.shape[:2]
center = (width//2, height//2)
radius = min(center)
cv.circle(mask, center, radius, (255,255,255), thickness=cv.FILLED)"""

# Rectangle
height, width = mask.shape[:2]
cv.rectangle(mask, (100, 100), (width-100, height-100), (255, 255 ,255), thickness=-1)

masked_img = cv.bitwise_and(img, mask)
cv.imshow("Original Image", img)
cv.imshow("Masked Image", masked_img)




cv.imshow("Original Image", img)
# cv.imshow("Saturated Image", sat_img)


cv.waitKey(0)
